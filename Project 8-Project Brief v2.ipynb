# %% [markdown]
# # Title: Diabetes and Possible Interventions
# Project 8 Group Members:
# 1.	S2164604/1	ELAINE LI
# 2.	S2174087/1	JUNHAO XU
# 3.	S2175919/1	HAOJIE CHU
# 4.	S2180377/1	YING MING TANG
# 5.	S2157792/1	PENGWEI LI
# 6.	S2174898/1	ZHENG WANG

# %% [markdown]
# ## Objective:
# 1. To predict the risk of having diabetes based on lifestyle.
# 2. To predict the level of diabetes (Type 1 diabetes, Type 2 diabetes, Prediabetes, Gestational Diabetes) based on lifestyle.
# 3. To predict the chance of having other diseases due to diabetes.

# %% [markdown]
# ## Dataset:
#
# Source: https://figshare.com/articles/dataset/EDDMQoL_Dataset_for_the_Study_on_Diabetes_Related_Distress_Depression_and_Distress_Depression_among_Adults_with_Type_2_Diabetes_Mellitus_in_Malaysia_sav/3103060/1
#
# 700 adults of the three main ethnicity in Malaysia on regular follow-ups and medical care at three public health clinics. Participants were at least 30 years of age, known T2DM for more than one year at the time of participating in the study in 2013.

# %%
import pandas as pd

# %%
path='C:\\Users\\USER\\Documents\\WQD7003 Data Analytics\\Group Project\\Diabetes Dataset.csv'# 替换策划给你自己的地址
data=pd.read_csv(path)
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    CodeCentre  Dengkil1  CodeNumber  Age  AgeGroups DiabetesDuration  \
# 0           1         2         275   68          3                5
# 1           1         2         112   65          3               33
# 2           1         2         141   56          2                9
# 3           1         2         295   61          3                5
# 4           1         2           5   58          2               20
#
#   DiabDuration3Cat  Gender Ethnic3Cat Religion6Cat  ... OHAothers Insulin  \
# 0                2       1          3            4  ...       999     999
# 1                3       1          2            3  ...         0       1
# 2                2       0          1            2  ...         0       0
# 3                2       0          2            1  ...         0       1
# 4                3       0          1            2  ...         0       1
#
#   Insulin2 AHAnumber AHAZeroto3 LLAnumber LLA2Cat APAnumber AHA0to3 APA2Cat
# ...

# %%
print(data.shape)
data.describe()
# Out:
# (700, 106)
#        CodeCentre    Dengkil1  CodeNumber         Age   AgeGroups      Gender  \
# count  700.000000  700.000000  700.000000  700.000000  700.000000  700.000000
# mean     2.184286    2.328571  166.702857   59.614286    4.927143    4.751429
# std      0.889638    0.756875  123.066867   51.337419   53.255226   65.277319
# min      1.000000    1.000000    1.000000   31.000000    1.000000    0.000000
# 25%      1.000000    2.000000   66.750000   50.000000    1.000000    0.000000
# 50%      3.000000    3.000000  138.500000   57.000000    2.000000    0.000000
# 75%      3.000000    3.000000  283.000000   64.000000    3.000000    1.000000
# max      3.000000    3.000000  434.000000  999.000000  999.000000  999.000000
#
#              DDS2        DDS4        DDS7       DDS10  ...        Diet  \
# count  700.000000  700.000000  700.000000  700.000000  ...  700.000000
# mean     6.701429    7.964286   15.148571    8.224286  ...   13.324286
# ...
